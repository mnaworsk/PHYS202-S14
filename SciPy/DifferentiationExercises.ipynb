# %% [markdown]
# Driver: Mary Naworski
#
# Navigator: Devin Vaage

# %% [markdown]
# # Differentiation Exercises

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Question 1

# %% [markdown]
# Let’s explore the accuracy of numerical differentiation.
# (a) Write two functions called twoPtForwardDiff(x,y) and twoPtCenteredDiff(x,y) that take as arguments arrays of values x and y(x) and return the derivatives of y with respect to x. Make sure that the arrays returned by the function have the same shape as the input arrays.

# %%
x = np.arange(0., 10.01, 0.1)
y = x**2
dydx = np.diff(y) / np.diff(x)

# %%
def twoPtForwardDiff(x,y): 
    """this function returns the derivative of the forward difference"""
    dydx1 = np.zeros(y.shape, float)
    dydx1[0:-1] = np.diff(y)/np.diff(x)
    dydx1[0] = (y[1]-y[0])/(x[1]-x[0]) #forward difference 
    return dydx1
print twoPtForwardDiff(x,y)
# Out:
# [  0.1   0.3   0.5   0.7   0.9   1.1   1.3   1.5   1.7   1.9   2.1   2.3
#    2.5   2.7   2.9   3.1   3.3   3.5   3.7   3.9   4.1   4.3   4.5   4.7
#    4.9   5.1   5.3   5.5   5.7   5.9   6.1   6.3   6.5   6.7   6.9   7.1
#    7.3   7.5   7.7   7.9   8.1   8.3   8.5   8.7   8.9   9.1   9.3   9.5
#    9.7   9.9  10.1  10.3  10.5  10.7  10.9  11.1  11.3  11.5  11.7  11.9
#   12.1  12.3  12.5  12.7  12.9  13.1  13.3  13.5  13.7  13.9  14.1  14.3
#   14.5  14.7  14.9  15.1  15.3  15.5  15.7  15.9  16.1  16.3  16.5  16.7
#   16.9  17.1  17.3  17.5  17.7  17.9  18.1  18.3  18.5  18.7  18.9  19.1
#   19.3  19.5  19.7  19.9   0. ]

# %%
def twoPtCenteredDiff(x,y): 
    """this function returns the derivative of the center difference"""
    dydx2 = np.zeros(y.shape, float) 
    
    dydx2[1:-1] = (y[2:] - y[:-2])/(x[2:] - x[:-2]) #center difference
    
    return dydx2

print twoPtCenteredDiff(x,y)
# Out:
# [  0.    0.2   0.4   0.6   0.8   1.    1.2   1.4   1.6   1.8   2.    2.2
#    2.4   2.6   2.8   3.    3.2   3.4   3.6   3.8   4.    4.2   4.4   4.6
#    4.8   5.    5.2   5.4   5.6   5.8   6.    6.2   6.4   6.6   6.8   7.
#    7.2   7.4   7.6   7.8   8.    8.2   8.4   8.6   8.8   9.    9.2   9.4
#    9.6   9.8  10.   10.2  10.4  10.6  10.8  11.   11.2  11.4  11.6  11.8
#   12.   12.2  12.4  12.6  12.8  13.   13.2  13.4  13.6  13.8  14.   14.2
#   14.4  14.6  14.8  15.   15.2  15.4  15.6  15.8  16.   16.2  16.4  16.6
#   16.8  17.   17.2  17.4  17.6  17.8  18.   18.2  18.4  18.6  18.8  19.
#   19.2  19.4  19.6  19.8   0. ]

# %% [markdown]
# (b) Use your functions to take the derivative of the function y=8x4+3x over the range 0 <x< 10, with steps of 0.1. How do you know they work correctly? (Hint: compare to the analytical result).

# %%
newx = np.arange(0, 10, 0.1)
newy = (8*(newx**4) + 3*newx)
newdydx = np.diff(newy) / np.diff(newx)

def twoPtCenteredDiff(newx,newy): 
    """this function returns the derivative of the center difference"""
    dydx3 = np.zeros(newy.shape, float) 
    
    dydx3[1:-1] = (newy[2:] - newy[:-2])/(newx[2:] - newx[:-2]) #center difference
    
    return dydx3

print twoPtCenteredDiff(newx,newy)

#How we know they work correctly
dydxExact = 32*x**3 + 3

print dydxExact
# Out:
# [  0.00000000e+00   3.06400000e+00   3.32000000e+00   3.96000000e+00
#    5.17600000e+00   7.16000000e+00   1.01040000e+01   1.42000000e+01
#    1.96400000e+01   2.66160000e+01   3.53200000e+01   4.59440000e+01
#    5.86800000e+01   7.37200000e+01   9.12560000e+01   1.11480000e+02
#    1.34584000e+02   1.60760000e+02   1.90200000e+02   2.23096000e+02
#    2.59640000e+02   3.00024000e+02   3.44440000e+02   3.93080000e+02
#    4.46136000e+02   5.03800000e+02   5.66264000e+02   6.33720000e+02
#    7.06360000e+02   7.84376000e+02   8.67960000e+02   9.57304000e+02
#    1.05260000e+03   1.15404000e+03   1.26181600e+03   1.37612000e+03
#    1.49714400e+03   1.62508000e+03   1.76012000e+03   1.90245600e+03
#    2.05228000e+03   2.20978400e+03   2.37516000e+03   2.54860000e+03
#    2.73029600e+03   2.92044000e+03   3.11922400e+03   3.32684000e+03
#    3.54348000e+03   3.76933600e+03   4.00460000e+03   4.24946400e+03
#    4.50412000e+03   4.76876000e+03   5.04357600e+03   5.32876000e+03
#    5.62450400e+03   5.93100000e+03   6.24844000e+03   6.57701600e+03
#    6.91692000e+03   7.26834400e+03   7.63148000e+03   8.00652000e+03
#    8.39365600e+03   8.79308000e+03   9.20498400e+03   9.62956000e+03
#    1.00670000e+04   1.05174960e+04   1.09812400e+04   1.14584240e+04
#    1.19492400e+04   1.24538800e+04   1.29725360e+04   1.35054000e+04
#    1.40526640e+04   1.46145200e+04   1.51911600e+04   1.57827760e+04
#    1.63895600e+04   1.70117040e+04   1.76494000e+04   1.83028400e+04
#    1.89722160e+04   1.96577200e+04   2.03595440e+04   2.10778800e+04
#    2.18129200e+04   2.25648560e+04   2.33338800e+04   2.41201840e+04
#    2.49239600e+04   2.57454000e+04   2.65846960e+04   2.74420400e+04
#    2.83176240e+04   2.92116400e+04   3.01242800e+04   0.00000000e+00]
# [  3.00000000e+00   3.03200000e+00   3.25600000e+00   3.86400000e+00
#    5.04800000e+00   7.00000000e+00   9.91200000e+00   1.39760000e+01
#    1.93840000e+01   2.63280000e+01   3.50000000e+01   4.55920000e+01
#    5.82960000e+01   7.33040000e+01   9.08080000e+01   1.11000000e+02
#    1.34072000e+02   1.60216000e+02   1.89624000e+02   2.22488000e+02
#    2.59000000e+02   2.99352000e+02   3.43736000e+02   3.92344000e+02
#    4.45368000e+02   5.03000000e+02   5.65432000e+02   6.32856000e+02
#    7.05464000e+02   7.83448000e+02   8.67000000e+02   9.56312000e+02
#    1.05157600e+03   1.15298400e+03   1.26072800e+03   1.37500000e+03
#    1.49599200e+03   1.62389600e+03   1.75890400e+03   1.90120800e+03
#    2.05100000e+03   2.20847200e+03   2.37381600e+03   2.54722400e+03
#    2.72888800e+03   2.91900000e+03   3.11775200e+03   3.32533600e+03
#    3.54194400e+03   3.76776800e+03   4.00300000e+03   4.24783200e+03
#    4.50245600e+03   4.76706400e+03   5.04184800e+03   5.32700000e+03
#    5.62271200e+03   5.92917600e+03   6.24658400e+03   6.57512800e+03
#    6.91500000e+03   7.26639200e+03   7.62949600e+03   8.00450400e+03
#    8.39160800e+03   8.79100000e+03   9.20287200e+03   9.62741600e+03
#    1.00648240e+04   1.05152880e+04   1.09790000e+04   1.14561520e+04
#    1.19469360e+04   1.24515440e+04   1.29701680e+04   1.35030000e+04
#    1.40502320e+04   1.46120560e+04   1.51886640e+04   1.57802480e+04
#    1.63870000e+04   1.70091120e+04   1.76467760e+04   1.83001840e+04
#    1.89695280e+04   1.96550000e+04   2.03567920e+04   2.10750960e+04
#    2.18101040e+04   2.25620080e+04   2.33310000e+04   2.41172720e+04
#    2.49210160e+04   2.57424240e+04   2.65816880e+04   2.74390000e+04
#    2.83145520e+04   2.92085360e+04   3.01211440e+04   3.10525680e+04]

# %% [markdown]
# (c) What is the accuracy of the results if you use a spacing of 0.01? (Plot the relative error)

# %%
#must set endpoint manually for forward
#must set first and last point manually for centered(go 1 ahead and 1 behind)

#dydx = y[-2]- y[-1] / x[-2] - x[-1]

newx = np.arange(0, 10, 0.01)
newy = (8*(newx**4) + 3*newx)
newdydx = np.diff(newy) / np.diff(newx)

def twoPtCenteredDiff(newx,newy): 
    """this function returns the derivative of the center difference"""
    dydx3 = np.zeros(newy.shape, float) 
    
    dydx3[1:-1] = (newy[2:] - newy[:-2])/(newx[2:] - newx[:-2]) #center difference
    
    return dydx3
    

print twoPtCenteredDiff(newx,newy)

dydxExact = np.zeros(y.shape, float)

percentError1 = 100*abs( newdydx[1:] - dydxExact[1:] )/dydxExact[1:]
plt.semilogy(x[1:], percentError1, label='forward difference')
plt.show()
# Out:
# [  0.00000000e+00   3.00006400e+00   3.00032000e+00   3.00096000e+00
#    3.00217600e+00   3.00416000e+00   3.00710400e+00   3.01120000e+00
#    3.01664000e+00   3.02361600e+00   3.03232000e+00   3.04294400e+00
#    3.05568000e+00   3.07072000e+00   3.08825600e+00   3.10848000e+00
#    3.13158400e+00   3.15776000e+00   3.18720000e+00   3.22009600e+00
#    3.25664000e+00   3.29702400e+00   3.34144000e+00   3.39008000e+00
#    3.44313600e+00   3.50080000e+00   3.56326400e+00   3.63072000e+00
#    3.70336000e+00   3.78137600e+00   3.86496000e+00   3.95430400e+00
#    4.04960000e+00   4.15104000e+00   4.25881600e+00   4.37312000e+00
#    4.49414400e+00   4.62208000e+00   4.75712000e+00   4.89945600e+00
#    5.04928000e+00   5.20678400e+00   5.37216000e+00   5.54560000e+00
#    5.72729600e+00   5.91744000e+00   6.11622400e+00   6.32384000e+00
#    6.54048000e+00   6.76633600e+00   7.00160000e+00   7.24646400e+00
#    7.50112000e+00   7.76576000e+00   8.04057600e+00   8.32576000e+00
#    8.62150400e+00   8.92800000e+00   9.24544000e+00   9.57401600e+00
#    9.91392000e+00   1.02653440e+01   1.06284800e+01   1.10035200e+01
#    1.13906560e+01   1.17900800e+01   1.22019840e+01   1.26265600e+01
#    1.30640000e+01   1.35144960e+01   1.39782400e+01   1.44554240e+01
#    1.49462400e+01   1.54508800e+01   1.59695360e+01   1.65024000e+01
#    1.70496640e+01   1.76115200e+01   1.81881600e+01   1.87797760e+01
#    1.93865600e+01   2.00087040e+01   2.06464000e+01   2.12998400e+01
#    2.19692160e+01   2.26547200e+01   2.33565440e+01   2.40748800e+01
#    2.48099200e+01   2.55618560e+01   2.63308800e+01   2.71171840e+01
#    2.79209600e+01   2.87424000e+01   2.95816960e+01   3.04390400e+01
#    3.13146240e+01   3.22086400e+01   3.31212800e+01   3.40527360e+01
#    3.50032000e+01   3.59728640e+01   3.69619200e+01   3.79705600e+01
#    3.89989760e+01   4.00473600e+01   4.11159040e+01   4.22048000e+01
#    4.33142400e+01   4.44444160e+01   4.55955200e+01   4.67677440e+01
#    4.79612800e+01   4.91763200e+01   5.04130560e+01   5.16716800e+01
#    5.29523840e+01   5.42553600e+01   5.55808000e+01   5.69288960e+01
#    5.82998400e+01   5.96938240e+01   6.11110400e+01   6.25516800e+01
#    6.40159360e+01   6.55040000e+01   6.70160640e+01   6.85523200e+01
#    7.01129600e+01   7.16981760e+01   7.33081600e+01   7.49431040e+01
#    7.66032000e+01   7.82886400e+01   7.99996160e+01   8.17363200e+01
#    8.34989440e+01   8.52876800e+01   8.71027200e+01   8.89442560e+01
#    9.08124800e+01   9.27075840e+01   9.46297600e+01   9.65792000e+01
#    9.85560960e+01   1.00560640e+02   1.02593024e+02   1.04653440e+02
#    1.06742080e+02   1.08859136e+02   1.11004800e+02   1.13179264e+02
#    1.15382720e+02   1.17615360e+02   1.19877376e+02   1.22168960e+02
#    1.24490304e+02   1.26841600e+02   1.29223040e+02   1.31634816e+02
#    1.34077120e+02   1.36550144e+02   1.39054080e+02   1.41589120e+02
#    1.44155456e+02   1.46753280e+02   1.49382784e+02   1.52044160e+02
#    1.54737600e+02   1.57463296e+02   1.60221440e+02   1.63012224e+02
#    1.65835840e+02   1.68692480e+02   1.71582336e+02   1.74505600e+02
#    1.77462464e+02   1.80453120e+02   1.83477760e+02   1.86536576e+02
#    1.89629760e+02   1.92757504e+02   1.95920000e+02   1.99117440e+02
#    2.02350016e+02   2.05617920e+02   2.08921344e+02   2.12260480e+02
#    2.15635520e+02   2.19046656e+02   2.22494080e+02   2.25977984e+02
#    2.29498560e+02   2.33056000e+02   2.36650496e+02   2.40282240e+02
#    2.43951424e+02   2.47658240e+02   2.51402880e+02   2.55185536e+02
#    2.59006400e+02   2.62865664e+02   2.66763520e+02   2.70700160e+02
#    2.74675776e+02   2.78690560e+02   2.82744704e+02   2.86838400e+02
#    2.90971840e+02   2.95145216e+02   2.99358720e+02   3.03612544e+02
#    3.07906880e+02   3.12241920e+02   3.16617856e+02   3.21034880e+02
#    3.25493184e+02   3.29992960e+02   3.34534400e+02   3.39117696e+02
#    3.43743040e+02   3.48410624e+02   3.53120640e+02   3.57873280e+02
#    3.62668736e+02   3.67507200e+02   3.72388864e+02   3.77313920e+02
#    3.82282560e+02   3.87294976e+02   3.92351360e+02   3.97451904e+02
#    4.02596800e+02   4.07786240e+02   4.13020416e+02   4.18299520e+02
#    4.23623744e+02   4.28993280e+02   4.34408320e+02   4.39869056e+02
#    4.45375680e+02   4.50928384e+02   4.56527360e+02   4.62172800e+02
#    4.67864896e+02   4.73603840e+02   4.79389824e+02   4.85223040e+02
#    4.91103680e+02   4.97031936e+02   5.03008000e+02   5.09032064e+02
#    5.15104320e+02   5.21224960e+02   5.27394176e+02   5.33612160e+02
#    5.39879104e+02   5.46195200e+02   5.52560640e+02   5.58975616e+02
#    5.65440320e+02   5.71954944e+02   5.78519680e+02   5.85134720e+02
#    5.91800256e+02   5.98516480e+02   6.05283584e+02   6.12101760e+02
#    6.18971200e+02   6.25892096e+02   6.32864640e+02   6.39889024e+02
#    6.46965440e+02   6.54094080e+02   6.61275136e+02   6.68508800e+02
#    6.75795264e+02   6.83134720e+02   6.90527360e+02   6.97973376e+02
#    7.05472960e+02   7.13026304e+02   7.20633600e+02   7.28295040e+02
#    7.36010816e+02   7.43781120e+02   7.51606144e+02   7.59486080e+02
#    7.67421120e+02   7.75411456e+02   7.83457280e+02   7.91558784e+02
#    7.99716160e+02   8.07929600e+02   8.16199296e+02   8.24525440e+02
#    8.32908224e+02   8.41347840e+02   8.49844480e+02   8.58398336e+02
#    8.67009600e+02   8.75678464e+02   8.84405120e+02   8.93189760e+02
#    9.02032576e+02   9.10933760e+02   9.19893504e+02   9.28912000e+02
#    9.37989440e+02   9.47126016e+02   9.56321920e+02   9.65577344e+02
#    9.74892480e+02   9.84267520e+02   9.93702656e+02   1.00319808e+03
#    1.01275398e+03   1.02237056e+03   1.03204800e+03   1.04178650e+03
#    1.05158624e+03   1.06144742e+03   1.07137024e+03   1.08135488e+03
#    1.09140154e+03   1.10151040e+03   1.11168166e+03   1.12191552e+03
#    1.13221216e+03   1.14257178e+03   1.15299456e+03   1.16348070e+03
#    1.17403040e+03   1.18464384e+03   1.19532122e+03   1.20606272e+03
#    1.21686854e+03   1.22773888e+03   1.23867392e+03   1.24967386e+03
#    1.26073888e+03   1.27186918e+03   1.28306496e+03   1.29432640e+03
#    1.30565370e+03   1.31704704e+03   1.32850662e+03   1.34003264e+03
#    1.35162528e+03   1.36328474e+03   1.37501120e+03   1.38680486e+03
#    1.39866592e+03   1.41059456e+03   1.42259098e+03   1.43465536e+03
#    1.44678790e+03   1.45898880e+03   1.47125824e+03   1.48359642e+03
#    1.49600352e+03   1.50847974e+03   1.52102528e+03   1.53364032e+03
#    1.54632506e+03   1.55907968e+03   1.57190438e+03   1.58479936e+03
#    1.59776480e+03   1.61080090e+03   1.62390784e+03   1.63708582e+03
#    1.65033504e+03   1.66365568e+03   1.67704794e+03   1.69051200e+03
#    1.70404806e+03   1.71765632e+03   1.73133696e+03   1.74509018e+03
#    1.75891616e+03   1.77281510e+03   1.78678720e+03   1.80083264e+03
#    1.81495162e+03   1.82914432e+03   1.84341094e+03   1.85775168e+03
#    1.87216672e+03   1.88665626e+03   1.90122048e+03   1.91585958e+03
#    1.93057376e+03   1.94536320e+03   1.96022810e+03   1.97516864e+03
#    1.99018502e+03   2.00527744e+03   2.02044608e+03   2.03569114e+03
#    2.05101280e+03   2.06641126e+03   2.08188672e+03   2.09743936e+03
#    2.11306938e+03   2.12877696e+03   2.14456230e+03   2.16042560e+03
#    2.17636704e+03   2.19238682e+03   2.20848512e+03   2.22466214e+03
#    2.24091808e+03   2.25725312e+03   2.27366746e+03   2.29016128e+03
#    2.30673478e+03   2.32338816e+03   2.34012160e+03   2.35693530e+03
#    2.37382944e+03   2.39080422e+03   2.40785984e+03   2.42499648e+03
#    2.44221434e+03   2.45951360e+03   2.47689446e+03   2.49435712e+03
#    2.51190176e+03   2.52952858e+03   2.54723776e+03   2.56502950e+03
#    2.58290400e+03   2.60086144e+03   2.61890202e+03   2.63702592e+03
#    2.65523334e+03   2.67352448e+03   2.69189952e+03   2.71035866e+03
#    2.72890208e+03   2.74752998e+03   2.76624256e+03   2.78504000e+03
#    2.80392250e+03   2.82289024e+03   2.84194342e+03   2.86108224e+03
#    2.88030688e+03   2.89961754e+03   2.91901440e+03   2.93849766e+03
#    2.95806752e+03   2.97772416e+03   2.99746778e+03   3.01729856e+03
#    3.03721670e+03   3.05722240e+03   3.07731584e+03   3.09749722e+03
#    3.11776672e+03   3.13812454e+03   3.15857088e+03   3.17910592e+03
#    3.19972986e+03   3.22044288e+03   3.24124518e+03   3.26213696e+03
#    3.28311840e+03   3.30418970e+03   3.32535104e+03   3.34660262e+03
#    3.36794464e+03   3.38937728e+03   3.41090074e+03   3.43251520e+03
#    3.45422086e+03   3.47601792e+03   3.49790656e+03   3.51988698e+03
#    3.54195936e+03   3.56412390e+03   3.58638080e+03   3.60873024e+03
#    3.63117242e+03   3.65370752e+03   3.67633574e+03   3.69905728e+03
#    3.72187232e+03   3.74478106e+03   3.76778368e+03   3.79088038e+03
#    3.81407136e+03   3.83735680e+03   3.86073690e+03   3.88421184e+03
#    3.90778182e+03   3.93144704e+03   3.95520768e+03   3.97906394e+03
#    4.00301600e+03   4.02706406e+03   4.05120832e+03   4.07544896e+03
#    4.09978618e+03   4.12422016e+03   4.14875110e+03   4.17337920e+03
#    4.19810464e+03   4.22292762e+03   4.24784832e+03   4.27286694e+03
#    4.29798368e+03   4.32319872e+03   4.34851226e+03   4.37392448e+03
#    4.39943558e+03   4.42504576e+03   4.45075520e+03   4.47656410e+03
#    4.50247264e+03   4.52848102e+03   4.55458944e+03   4.58079808e+03
#    4.60710714e+03   4.63351680e+03   4.66002726e+03   4.68663872e+03
#    4.71335136e+03   4.74016538e+03   4.76708096e+03   4.79409830e+03
#    4.82121760e+03   4.84843904e+03   4.87576282e+03   4.90318912e+03
#    4.93071814e+03   4.95835008e+03   4.98608512e+03   5.01392346e+03
#    5.04186528e+03   5.06991078e+03   5.09806016e+03   5.12631360e+03
#    5.15467130e+03   5.18313344e+03   5.21170022e+03   5.24037184e+03
#    5.26914848e+03   5.29803034e+03   5.32701760e+03   5.35611046e+03
#    5.38530912e+03   5.41461376e+03   5.44402458e+03   5.47354176e+03
#    5.50316550e+03   5.53289600e+03   5.56273344e+03   5.59267802e+03
#    5.62272992e+03   5.65288934e+03   5.68315648e+03   5.71353152e+03
#    5.74401466e+03   5.77460608e+03   5.80530598e+03   5.83611456e+03
#    5.86703200e+03   5.89805850e+03   5.92919424e+03   5.96043942e+03
#    5.99179424e+03   6.02325888e+03   6.05483354e+03   6.08651840e+03
#    6.11831366e+03   6.15021952e+03   6.18223616e+03   6.21436378e+03
#    6.24660256e+03   6.27895270e+03   6.31141440e+03   6.34398784e+03
#    6.37667322e+03   6.40947072e+03   6.44238054e+03   6.47540288e+03
#    6.50853792e+03   6.54178586e+03   6.57514688e+03   6.60862118e+03
#    6.64220896e+03   6.67591040e+03   6.70972570e+03   6.74365504e+03
#    6.77769862e+03   6.81185664e+03   6.84612928e+03   6.88051674e+03
#    6.91501920e+03   6.94963686e+03   6.98436992e+03   7.01921856e+03
#    7.05418298e+03   7.08926336e+03   7.12445990e+03   7.15977280e+03
#    7.19520224e+03   7.23074842e+03   7.26641152e+03   7.30219174e+03
#    7.33808928e+03   7.37410432e+03   7.41023706e+03   7.44648768e+03
#    7.48285638e+03   7.51934336e+03   7.55594880e+03   7.59267290e+03
#    7.62951584e+03   7.66647782e+03   7.70355904e+03   7.74075968e+03
#    7.77807994e+03   7.81552000e+03   7.85308006e+03   7.89076032e+03
#    7.92856096e+03   7.96648218e+03   8.00452416e+03   8.04268710e+03
#    8.08097120e+03   8.11937664e+03   8.15790362e+03   8.19655232e+03
#    8.23532294e+03   8.27421568e+03   8.31323072e+03   8.35236826e+03
#    8.39162848e+03   8.43101158e+03   8.47051776e+03   8.51014720e+03
#    8.54990010e+03   8.58977664e+03   8.62977702e+03   8.66990144e+03
#    8.71015008e+03   8.75052314e+03   8.79102080e+03   8.83164326e+03
#    8.87239072e+03   8.91326336e+03   8.95426138e+03   8.99538496e+03
#    9.03663430e+03   9.07800960e+03   9.11951104e+03   9.16113882e+03
#    9.20289312e+03   9.24477414e+03   9.28678208e+03   9.32891712e+03
#    9.37117946e+03   9.41356928e+03   9.45608678e+03   9.49873216e+03
#    9.54150560e+03   9.58440730e+03   9.62743744e+03   9.67059622e+03
#    9.71388384e+03   9.75730048e+03   9.80084634e+03   9.84452160e+03
#    9.88832646e+03   9.93226112e+03   9.97632576e+03   1.00205206e+04
#    1.00648458e+04   1.01093015e+04   1.01538880e+04   1.01986054e+04
#    1.02434540e+04   1.02884339e+04   1.03335453e+04   1.03787885e+04
#    1.04241635e+04   1.04696707e+04   1.05153101e+04   1.05610820e+04
#    1.06069866e+04   1.06530240e+04   1.06991945e+04   1.07454982e+04
#    1.07919354e+04   1.08385062e+04   1.08852109e+04   1.09320495e+04
#    1.09790224e+04   1.10261297e+04   1.10733715e+04   1.11207482e+04
#    1.11682598e+04   1.12159066e+04   1.12636887e+04   1.13116064e+04
#    1.13596598e+04   1.14078492e+04   1.14561747e+04   1.15046365e+04
#    1.15532349e+04   1.16019699e+04   1.16508419e+04   1.16998509e+04
#    1.17489972e+04   1.17982810e+04   1.18477024e+04   1.18972617e+04
#    1.19469590e+04   1.19967946e+04   1.20467686e+04   1.20968813e+04
#    1.21471327e+04   1.21975232e+04   1.22480529e+04   1.22987219e+04
#    1.23495306e+04   1.24004790e+04   1.24515674e+04   1.25027959e+04
#    1.25541648e+04   1.26056742e+04   1.26573244e+04   1.27091155e+04
#    1.27610477e+04   1.28131213e+04   1.28653363e+04   1.29176931e+04
#    1.29701917e+04   1.30228324e+04   1.30756154e+04   1.31285408e+04
#    1.31816089e+04   1.32348198e+04   1.32881738e+04   1.33416710e+04
#    1.33953117e+04   1.34490959e+04   1.35030240e+04   1.35570961e+04
#    1.36113123e+04   1.36656730e+04   1.37201782e+04   1.37748282e+04
#    1.38296231e+04   1.38845632e+04   1.39396486e+04   1.39948796e+04
#    1.40502563e+04   1.41057789e+04   1.41614477e+04   1.42172627e+04
#    1.42732243e+04   1.43293325e+04   1.43855876e+04   1.44419898e+04
#    1.44985392e+04   1.45552361e+04   1.46120806e+04   1.46690730e+04
#    1.47262134e+04   1.47835021e+04   1.48409391e+04   1.48985248e+04
#    1.49562593e+04   1.50141427e+04   1.50721754e+04   1.51303574e+04
#    1.51886890e+04   1.52471703e+04   1.53058016e+04   1.53645830e+04
#    1.54235148e+04   1.54825971e+04   1.55418301e+04   1.56012141e+04
#    1.56607491e+04   1.57204355e+04   1.57802733e+04   1.58402628e+04
#    1.59004042e+04   1.59606976e+04   1.60211433e+04   1.60817414e+04
#    1.61424922e+04   1.62033958e+04   1.62644525e+04   1.63256623e+04
#    1.63870256e+04   1.64485425e+04   1.65102131e+04   1.65720378e+04
#    1.66340166e+04   1.66961498e+04   1.67584375e+04   1.68208800e+04
#    1.68834774e+04   1.69462300e+04   1.70091379e+04   1.70722013e+04
#    1.71354205e+04   1.71987955e+04   1.72623267e+04   1.73260141e+04
#    1.73898580e+04   1.74538586e+04   1.75180160e+04   1.75823305e+04
#    1.76468022e+04   1.77114314e+04   1.77762182e+04   1.78411629e+04
#    1.79062655e+04   1.79715264e+04   1.80369457e+04   1.81025235e+04
#    1.81682602e+04   1.82341558e+04   1.83002106e+04   1.83664247e+04
#    1.84327984e+04   1.84993318e+04   1.85660252e+04   1.86328787e+04
#    1.86998925e+04   1.87670669e+04   1.88344019e+04   1.89018979e+04
#    1.89695549e+04   1.90373732e+04   1.91053530e+04   1.91734944e+04
#    1.92417977e+04   1.93102630e+04   1.93788906e+04   1.94476806e+04
#    1.95166333e+04   1.95857487e+04   1.96550272e+04   1.97244689e+04
#    1.97940739e+04   1.98638426e+04   1.99337750e+04   2.00038714e+04
#    2.00741319e+04   2.01445568e+04   2.02151462e+04   2.02859004e+04
#    2.03568195e+04   2.04279037e+04   2.04991533e+04   2.05705683e+04
#    2.06421491e+04   2.07138957e+04   2.07858084e+04   2.08578874e+04
#    2.09301328e+04   2.10025449e+04   2.10751238e+04   2.11478698e+04
#    2.12207830e+04   2.12938637e+04   2.13671119e+04   2.14405280e+04
#    2.15141121e+04   2.15878643e+04   2.16617850e+04   2.17358742e+04
#    2.18101322e+04   2.18845591e+04   2.19591552e+04   2.20339206e+04
#    2.21088556e+04   2.21839603e+04   2.22592349e+04   2.23346797e+04
#    2.24102947e+04   2.24860803e+04   2.25620365e+04   2.26381636e+04
#    2.27144618e+04   2.27909312e+04   2.28675721e+04   2.29443846e+04
#    2.30213690e+04   2.30985254e+04   2.31758541e+04   2.32533551e+04
#    2.33310288e+04   2.34088753e+04   2.34868947e+04   2.35650874e+04
#    2.36434534e+04   2.37219930e+04   2.38007063e+04   2.38795936e+04
#    2.39586550e+04   2.40378908e+04   2.41173011e+04   2.41968861e+04
#    2.42766461e+04   2.43565811e+04   2.44366915e+04   2.45169773e+04
#    2.45974388e+04   2.46780762e+04   2.47588896e+04   2.48398793e+04
#    2.49210454e+04   2.50023882e+04   2.50839078e+04   2.51656045e+04
#    2.52474783e+04   2.53295296e+04   2.54117585e+04   2.54941651e+04
#    2.55767498e+04   2.56595126e+04   2.57424538e+04   2.58255735e+04
#    2.59088720e+04   2.59923494e+04   2.60760060e+04   2.61598419e+04
#    2.62438573e+04   2.63280525e+04   2.64124275e+04   2.64969827e+04
#    2.65817181e+04   2.66666340e+04   2.67517306e+04   2.68370080e+04
#    2.69224665e+04   2.70081062e+04   2.70939274e+04   2.71799302e+04
#    2.72661149e+04   2.73524815e+04   2.74390304e+04   2.75257617e+04
#    2.76126755e+04   2.76997722e+04   2.77870518e+04   2.78745146e+04
#    2.79621607e+04   2.80499904e+04   2.81380038e+04   2.82262012e+04
#    2.83145827e+04   2.84031485e+04   2.84918989e+04   2.85808339e+04
#    2.86699539e+04   2.87592589e+04   2.88487492e+04   2.89384250e+04
#    2.90282864e+04   2.91183337e+04   2.92085670e+04   2.92989866e+04
#    2.93895926e+04   2.94803853e+04   2.95713647e+04   2.96625312e+04
#    2.97538849e+04   2.98454259e+04   2.99371546e+04   3.00290710e+04
#    3.01211754e+04   3.02134679e+04   3.03059488e+04   3.03986182e+04
#    3.04914764e+04   3.05845235e+04   3.06777597e+04   3.07711853e+04
#    3.08648003e+04   3.09586051e+04   3.10525997e+04   3.11467844e+04
#    3.12411594e+04   3.13357248e+04   3.14304809e+04   3.15254278e+04
#    3.16205658e+04   3.17158950e+04   3.18114157e+04   0.00000000e+00]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-6e8524796a9e> in <module>()
#      21 dydxExact = np.zeros(y.shape, float)
#      22
# ---> 23 percentError1 = 100*abs( newdydx[1:] - dydxExact[1:] )/dydxExact[1:]
#      24 plt.semilogy(x[1:], percentError1, label='forward difference')
#      25 plt.show()
#
# ValueError: operands could not be broadcast together with shapes (998) (99)

# %% [markdown]
# (d) For what minimum spacing is the 2pt-centered difference derivative accurate to 5 significant figures over its full range (excluding the last point)?

# %% [markdown]
# ## Question 2

# %% [markdown]
# (a) Now that we do not control the spacing of the data points, we have to use higher order differencing methods to reach a smoother and more accurate derivative. The four-point center differencing method is defined by
# dydx[i]≃y[i−2]−8y[i−1]+8y[i+1]−y[i+2]12h
# where h is the spacing between points on the x axis (assumed to be equal). This comes from keeping higher order terms from the Taylor expansion used to define the derivative. This method can be used to obtain dydx[2:-2]. In order to calculate values for dydx[0], dydx[1], dydx[-1] and dydx[-2] you must use the lowest order finite difference method (like the ones you defined in your twoPtForwardDiff(x,y) and twoPtCenteredDiff(x,y) functions). Create another function, fourPtCenteredDiff(x,y), that computes the derivative using the higher order method above. Test that it works for y=8x4+3x and plot the relative error from the analytical result.

# %%
x = np.linspace(0, 2*pi, 100)
y = np.sin(x) + 0.1*random.random(size=x.shape)
plot(x,y)

# %%
    dydx4 = np.zeros(y.shape, float) 
    dydx4[2:-2] = (y[4:] - y[:-4])/(x[4:] - x[:-4]) #center difference
    
def fourPtCenteredDiff(x,y): 

    dydx[i] = y[i−2]−8y[i−1]+8y[i+1]−y[i+2]12*4
              
percentError2 = 100*abs( dydx4[1:] - dydxExact[1:] )/dydxExact[1:]
plt.semilogy(x[1:], percentError1, label='forward difference')
plt.show()
# Out:
#   File "<ipython-input-80-45a8e4765301>", line 2
#     dydx4 = np.zeros(y.shape, float)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# (b) Now plot the noisy sine function along with the derivatives computed analytically, using the lowest order forward finite difference method and the four-point centered difference.

# %% [markdown]
# (c) Write your three differentiating functions to a file called Differentiators.py. Be sure to include meaningful docstrings that describe what the functions do. The docstrings should include enough information for someone to understand the differences between the algorithms. Test that the code works by importing the functions and calling them on y=8x4+3x. Plot the results from all three methods.

# %%
# %%file Differentiators.py

newx = np.arange(0, 10, 0.01)
newy = (8*(newx**4) + 3*newx)
newdydx = np.diff(newy) / np.diff(newx)

def twoPtCenteredDiff(newx,newy): 
    """this function returns the derivative of the center difference"""
    dydx3 = np.zeros(newy.shape, float) 
    
    dydx3[1:-1] = (newy[2:] - newy[:-2])/(newx[2:] - newx[:-2]) #center difference
    
    return dydx3

def twoPtForwardDiff(x,y): 
    """this function returns the derivative of the forward difference"""
    dydx1 = np.zeros(y.shape, float)
    dydx1[0:-1] = np.diff(y)/np.diff(x)
    dydx1[0] = (y[1]-y[0])/(x[1]-x[0]) #forward difference 
    return dydx1

def fourPtCenteredDiff(x,y): 

    dydx[i] = y[i−2]−8y[i−1]+8y[i+1]−y[i+2]12*4



y = 8x**4 + 3x
